# %%
from topologies_triple_task_training_sweep import unified_training_function

# %%
unified_training_function('batch')
# Out:
# 🚀 Running triple-task training in standalone mode...
# 📋 Loading configuration: batch
# 🚀 Batch run detected: 36 individual runs will be executed
#
# 📋 Batch Run Summary:
# ...
#    • Topology types: 4 (modular, small_world, hybrid, fully_connected)
#    • Hidden sizes: 3 (64, 128, 256)
#    • Task orders: 3
#      1. CartPole-v1_Acrobot-v1_LunarLander-v2
#      2. Acrobot-v1_LunarLander-v2_CartPole-v1
#      3. LunarLander-v2_CartPole-v1_Acrobot-v1
#    • Learning rate: 0.0003
#    • Batch size: 64
#    • Total timesteps: 600,000
# ...
#
# ...
# 🏃‍♂️ Running individual run 1/36
#    Topology: modular
#    Hidden Size: 64
#    Task Order: CartPole-v1_Acrobot-v1_LunarLander-v2
# ...
# 🔧 Initializing new logging system for modular topology...
# wandb: Currently logged in as: katko (katko-it-universitetet-i-k-benhavn) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# ...
